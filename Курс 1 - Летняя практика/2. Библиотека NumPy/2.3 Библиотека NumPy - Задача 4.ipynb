# %%
import numpy as np

# %% [markdown]
# # Вариант 2
# Выполнить обработку элементов прямоугольной матрицы A, имеющей n строк и m столбцов. Разделить элементы каждой строки на элемент этой строки с наибольшим значением.

# %%
""" Задаётся матрица, состоящая из целых чисел. """
a = np.array([[ 1, 0, 4, 2],
              [16, 8, 3, 1],
              [10, 5, 2, 0]])

"""
Ранее заданная матрица делится на строку,
состоящую из максимумов каждой из строк этой матрицы.
"""
a = a / a.max(axis=1).reshape(-1, 1)
a
# Out:
# array([[0.25  , 0.    , 1.    , 0.5   ],
#        [1.    , 0.5   , 0.1875, 0.0625],
#        [1.    , 0.5   , 0.2   , 0.    ]])
