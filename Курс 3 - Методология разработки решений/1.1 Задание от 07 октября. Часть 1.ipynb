# %% [markdown]
# ## Задача 1: Пропущенный KNN

# %% [markdown]
# ### Условие

# %% [markdown]
# Вася решает задачу классификации на два класса с помощью алгоритма KNN с количеством соседей 1. В обучающем датасете Васи 4 точки. Вася построил разделяющую поверхность, которая получилась у его алгоритма (см. рисунок). Красные точки плоскости алгоритм относит к классу 0, зеленые точки плоскости алгоритм относит к классу 1.
#
# Пока Вася пил чай, в компьютере произошел сбой, и один элементов датасета пропал. Помогите Васе восстановить четвертый элемент $x_4$, зная первые три элемента и координаты точкек $a_1$ и $a_2$:
#
# • $x_1 = (-2, 3)$
#
# • $x_2 = (2, 8)$
#
# • $x_3 = (1, 1)$
#
# • $a_1 = (17/18, 25/6)$
#
# • $a_2 = (15/22, 109/22)$

# %% [markdown]
# ![Screenshot 2024-05-29 at 19.38.06.png](data:image/png;base64,...)

# %% [markdown]
# ### Решение

# %% [markdown]
# Имеем KNN с $k = 1$ и 4 точки обучающей выборки. Разделяющая поверхность — это граница между областями Вороного для этих 4 точек. Если $a_1$ лежит на разделяющей поверхности, то расстояние от $a_1$ до двух (или более) точек одинаково и минимально среди всех точек.

# %% [markdown]
# Вычислим расстояния от $a_1$ до $x_1$, $x_2$, $x_3$.
#
# $$
# d(a_1, x_1) = \sqrt{(\frac{17}{18} - (-2))^2 + (\frac{25}{6} - 3)^2} \approx 3.167
# $$
#
# $$
# d(a_1, x_2) = \sqrt{(\frac{17}{18} - 2)^2 + (\frac{25}{6} - 8)^2} \approx 3.976
# $$
#
# $$
# d(a_1, x_3) = \sqrt{(\frac{17}{18} - 1)^2 + (\frac{25}{6} - 1)^2} \approx 3.167
# $$
#
# Получаем, что $d(a_1, x_1) \approx d(a_1, x_3) \approx 3.167$ и $d(a_1, x_2) \approx 3.978$.
#
# Значит, $a_1$ лежит на разделяющей поверхности между $x_1$ и $x_3$, если не влияет $x_4$.

# %% [markdown]
# Вычислим расстояния от $a_2$ до $x_1$, $x_2$, $x_3$.
#
# $$
# d(a_2, x_1) = \sqrt{(\frac{15}{22} - (-2))^2 + (\frac{109}{22} - 3)^2} \approx 3.318
# $$
#
# $$
# d(a_2, x_2) = \sqrt{(\frac{15}{22} - 2)^2 + (\frac{109}{22} - 8)^2} \approx 3.318
# $$
#
# $$
# d(a_2, x_3) = \sqrt{(\frac{15}{22} - 1)^2 + (\frac{109}{22} - 1)^2} \approx 3.967
# $$
#
# Получаем, что $d(a_2, x_1) \approx d(a_2, x_2) \approx 3.318$ и $d(a_2, x_3) \approx 3.967$.
#
# Значит, $a_2$ лежит на разделяющей поверхности между $x_1$ и $x_2$, если не влияет $x_4$.

# %% [markdown]
# Имеем две точки $a_1$ и $a_2$ на разделяющей поверхности. В KNN с $k = 1$ разделяющая поверхность состоит из отрезков серединных перпендикуляров между парами точек разных классов. Значит, $x_4$ должен быть такого класса, чтобы граница между ним и какой-то из точек $x_1$, $x_2$, $x_3$ проходила через $a_1$ или $a_2$.

# %% [markdown]
# Предположим, что $a_1$ равноудалена от $x_4$ и $x_1$.
#
# $$
# d(a_1, x_1) = (\frac{17}{18} - (-2))^2 + (\frac{25}{6} - 3)^2 = \frac{1625}{162}
# $$
#
# Пусть $x_4 = (p, q)$. Тогда $d(a_1, x_4) = d(a_1, x_1)$:
#
# $$
# (p - \frac{17}{18})^2 + (q - \frac{25}{6})^2 = \frac{1625}{162} \quad (1)
# $$

# %% [markdown]
# Предположим, что $a_2$ равноудалена от $x_4$ и $x_2$.
#
# $$
# d(a_2, x_2) = (\frac{15}{22} - 2)^2 + (\frac{109}{22} - 8)^2 = \frac{2665}{242}
# $$
#
# Тогда $d(a_2, x_4) = d(a_2, x_2)$:
#
# $$
# (p - \frac{15}{22})^2 + (q - \frac{109}{22})^2 = \frac{2665}{242} \quad (2)
# $$

# %% [markdown]
# Вычтем (1) из (2) и раскроем полные квадраты:
#
# $$
# p^2 - \frac{15}{11}p + \frac{225}{484} + q^2 - \frac{109}{11}q + \frac{11881}{484} - p^2 + \frac{17}{9}p - \frac{289}{324} - q^2 + \frac{25}{3}q - \frac{625}{36} = \frac{2665}{242} - \frac{1625}{162}
# $$
#
# $$
# (p^2 - p^2) + (q^2 - q^2) + (-\frac{15}{11}p + \frac{17}{9}p) + (-\frac{109}{11}q + \frac{25}{3}q) + (\frac{225}{484} + \frac{11881}{484} - \frac{2665}{242}) + (-\frac{289}{324} - \frac{625}{36} + \frac{1625}{162}) = 0
# $$
#
# $$
# \frac{52}{99}p - \frac{52}{33}q + 14 - \frac{74}{9} = 0
# $$
#
# $$
# \frac{52}{99}p - \frac{52}{33}q + \frac{52}{9} = 0
# $$
#
# $$
# \frac{1}{33}p - \frac{1}{11}q + \frac{1}{3} = 0
# $$
#
# $$
# p = 3q - 11
# $$

# %% [markdown]
# Подставим $p = 3q - 11$ в (1):
#
# $$
# (3q - 11 - \frac{17}{18})^2 + (q - \frac{25}{6})^2 = \frac{1625}{162}
# $$
#
# $$
# (3q - \frac{215}{18})^2 + (q - \frac{25}{6})^2 = \frac{1625}{162}
# $$
#
# $$
# 9q^2 - \frac{215}{3}q + \frac{46225}{324} + q^2 - \frac{25}{3}q + \frac{625}{36} - \frac{1625}{162} = 0
# $$
#
# $$
# 10q^2 - 80q + 150 = 0
# $$
#
# $$
# q^2 - 8q + 15 = 0
# $$
#
# $$
# (q - 3)(q - 5) = 0
# $$
#
# Таким образом, $q = 3$ или $q = 5$.

# %% [markdown]
# Проверяем получившиеся точки:
#
# При $q = 3$ получаем $p = 3 \cdot 3 - 11 = -2$. Т. е. имеем точку $(-2, 3)$, совпадающую с точкой $x_1$.
#
# При $q = 5$ получаем $p = 3 \cdot 5 - 11 = 4$. Т. е. имеем точку $(4, 5)$ — предположительно искомая $x_4$.

# %% [markdown]
# Проверим, что $a_1$ равноудалена от $x_1$ и $(4, 5)$.
#
# $$
# d(a_1, (4, 5)) = \sqrt{(\frac{17}{18} - 4)^2 + (\frac{25}{6} - 5)^2} \approx 3.167 \approx d(a_1, x_1)
# $$

# %% [markdown]
# Проверим, что $a_2$ равноудалена от $x_2$ и $(4, 5)$.
#
# $$
# d(a_2, (4, 5)) = \sqrt{(\frac{15}{22} - 4)^2 + (\frac{109}{22} - 5)^2} \approx 3.318 \approx d(a_2, x_2)
# $$

# %% [markdown]
# Таким образом, $x_4 = (4, 5)$.

# %% [markdown]
# **Ответ** — 4, 5

# %% [markdown]
# ## Задача 2: Решающие деревья для Феди

# %% [markdown]
# ### Условие

# %% [markdown]
# Никита — электротехник, сын которого, Федя, изучает машинное обучение. Никита придумал конструктор, имитирующий работу решающего дерева для решения задачи бинарной классификации точек на плоскости, где точка описывается признаками $(x_1, x_2)$. Каждой вершине решающего дерева (включая листы) соответствует один элемент конструктора. Конструктор позволяет строить только деревья, решающие правила в вершинах которого имеют вид $[x_i > C]$ для произвольной константы $C$.
#
# Федя позвонил папе и сообщил, что придумал датасет для классификации на 2 класса из 100 различных точек, причём координаты $x_1$, $x_2$ пробегают все возможные значения от 1 до 10. При этом Федя забыл сказать папе, какие точки к какому классу принадлежат. Никите нужно взять на работе достаточное количество элементов конструктора, чтобы Федя смог построить решающее дерево вне зависимости от того, каким классам принадлежат точки. Какое количество элементов ему понадобится?
#
# Иными словами, найдите такое минимальное число $N$, что, вне зависимости от разбиения точек на 2 класса, найдётся решающее дерево, идеально решающее эту задачу классификации, состоящее не более чем из $N$ вершин.

# %% [markdown]
# ### Решение

# %% [markdown]
# Раз точки разделены на 2 класса и координаты точек пробегают все возможные значения от 1 до 10, а всего точек 100, то можно представить себе распределение данных точек, как квадратную область размером 10x10 клеток, каждая из которых закрашена одним из двух цветов в зависимости от класса точки.
#
# Таким образом, в худшем случае классы точек будут чередоваться так, что никакие две соседние клетки не будут одного цвета, как на шахматной доске. Тогда, чтобы точно классифицировать каждую точку с помощью дерева решений, потребуется сначала «разрезать» все точки по столбцам (например, с помощью порогов $[x_1 > 1.5]$, $[x_1 > 2.5]$ и т. д.), затем по строкам, а затем посмотреть на каждую точку по отдельности.
#
# Получаем, что в бинарном дереве для разделения 10 столбцов нужно 9 внутренних вершин вида $[x_1 > C]$, т. к. дерево с 10 листьями (различные столбцы) имеет 9 внутренних вершин. Потом каждый столбец необходимо разделить на 10 строк с помощью 9 аналогичных внутренних вершин вида $[x_2 > C]$. Т. к. столбцов всего 10, то получаем $10 \cdot 9 = 90$ внутренних вершин.
#
# Что касается листьев решающего дерева, то в худшем случае их потребуется 100, исходя из того, что при распределением точек в виде шахматной доски любая одноцветная область занимает ровно одну клетку, а таких клеток в квадратной области 10x10 будет 100.
#
# Поскольку полное бинарное дерево с $L$ листьями имеет ровно $2 \cdot L - 1$ вершин, то в данной задаче в худшем случае потребуется не менее $2 \cdot 100 - 1 = 199$ вершин. С другой стороны, 199 вершин достаточно для любого разбиения, потому что можно построить дерево, которое сначала разделяет точки по столбцам (9 вершин), затем в каждом столбцев по строкам (90 вершин) и 100 листьев.
#
# **Ответ** — Никите нужно взять 199 элементов конструктора, чтобы их гарантированно хватило для любого размеченного Федей набора точек.
